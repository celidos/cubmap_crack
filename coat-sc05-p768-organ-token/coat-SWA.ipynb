# %% [markdown]
# # CLEAN BUILD FROM SCRATCH MIT-B2 on patches 768x768

# %%
CURRENT_FOLD = 3

# %% [markdown]
# # imports

# %%
import random
from pathlib import Path

import numpy as np
import pandas as pd
import cv2 as cv
import os

from matplotlib import pyplot as plt
from glob import glob
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm
from IPython.display import clear_output

import albumentations as A
import albumentations.pytorch

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.optim.swa_utils import AveragedModel, SWALR

import torch.cuda.amp as amp
is_amp = True

# %%
img1 = cv.imread('./../data/train_images/10044.tiff')[:, :, ::-1]
plt.imshow(img1)
plt.show()

# %%
img2 = cv.imread('./../data/train_images_patches_768_overlap/10044_00010.png')[:, :, ::-1]
plt.imshow(img2)
plt.show()

# %%
# for fname in tqdm(glob('./../data/train_images_patches_768_overlap/*.png')):
#     img = cv.imread(fname)
#     cv.imwrite(fname, img[:, :, ::-1])

# %% [markdown]
# # data

# %%
ORGAN2ID = {
    'kidney' : 0,
    'prostate' : 1,
    'largeintestine' : 2,
    'spleen' : 3,
    'lung' : 4
}
ID2ORGAN = {v: k for k, v in ORGAN2ID.items()}

# %% [markdown]
# # model testing

# %%
from model_coat_daformer import *
from coat import *

# %% [markdown]
# ## data 768

# %%
TRAIN_CSV = './../data/train.csv'
TEST_CSV = './../data/test.csv'
TRAIN_IMAGES_DIR = './../data/train_images_patches_768_overlap/'
TRAIN_MASKS_DIR = './../data/train_masks_patches_768_overlap/'

N_CROSS_VALID_SPLITS = 5
RANDOM_SEED = 2022

SPATIAL_SIZE = 768 # размер патча

# %%
train_df = pd.read_csv(TRAIN_CSV)

# %%
def make_train_image_path(row):
    return os.path.join(TRAIN_IMAGES_DIR, str(row['id']) + '.png')

def make_train_mask_path(row):
    return os.path.join(TRAIN_MASKS_DIR, str(row['id']) + '.png')

def create_folds(df: pd.DataFrame, n_splits: int, random_seed: int) -> pd.DataFrame:
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_seed)
    for fold, (_, val_idx) in enumerate(skf.split(X=df, y=df["organ"])):
        df.loc[val_idx, "fold"] = int(fold)

    return df

# %%
train_df = create_folds(train_df, n_splits=N_CROSS_VALID_SPLITS, random_seed=RANDOM_SEED)

# %%
train_df.head()
# Out:
#       id     organ data_source  img_height  img_width  pixel_size  \
# 0  10044  prostate         HPA        3000       3000         0.4
# 1  10274  prostate         HPA        3000       3000         0.4
# 2  10392    spleen         HPA        3000       3000         0.4
# 3  10488      lung         HPA        3000       3000         0.4
# 4  10610    spleen         HPA        3000       3000         0.4
#
#    tissue_thickness                                                rle   age  \
# 0                 4  1459676 77 1462675 82 1465674 87 1468673 92 14...  37.0
# 1                 4  715707 2 718705 8 721703 11 724701 18 727692 3...  76.0
# 2                 4  1228631 20 1231629 24 1234624 40 1237623 47 12...  82.0
# 3                 4  3446519 15 3449517 17 3452514 20 3455510 24 34...  78.0
# 4                 4  478925 68 481909 87 484893 105 487863 154 4908...  21.0
#
#       sex  fold
# 0    Male   4.0
# 1    Male   0.0
# 2    Male   0.0
# 3    Male   0.0
# 4  Female   4.0

# %%
def make_768_dataset(df):
    new_df = []
    for index, row in df.iterrows():
        id = row['id']
        glb = list(glob(TRAIN_IMAGES_DIR + '{}_*.png'.format(id)))
        for fname in glb:
            newrow = dict()
            newrow['id'] = id
            newrow['image'] = fname
            newrow['mask'] = fname.replace('train_images_', 'train_masks_')
            newrow['organ'] = row['organ']
            newrow['pixel_size'] = row['pixel_size']
            newrow['fold'] = row['fold']
            
            new_df.append(newrow)
    return pd.DataFrame(new_df)

# %%
train_df_768 = make_768_dataset(train_df)
print(train_df_768.shape)
train_df_768.head()
# Out:
# (8658, 6)
#    fold     id                                              image  \
# 0   4.0  10044  ./../data/train_images_patches_768_overlap/100...
# 1   4.0  10044  ./../data/train_images_patches_768_overlap/100...
# 2   4.0  10044  ./../data/train_images_patches_768_overlap/100...
# 3   4.0  10044  ./../data/train_images_patches_768_overlap/100...
# 4   4.0  10044  ./../data/train_images_patches_768_overlap/100...
#
#                                                 mask     organ  pixel_size
# 0  ./../data/train_masks_patches_768_overlap/1004...  prostate         0.4
# 1  ./../data/train_masks_patches_768_overlap/1004...  prostate         0.4
# 2  ./../data/train_masks_patches_768_overlap/1004...  prostate         0.4
# 3  ./../data/train_masks_patches_768_overlap/1004...  prostate         0.4
# 4  ./../data/train_masks_patches_768_overlap/1004...  prostate         0.4

# %%
train_df_768.iloc[0]['image']
# Out:
# './../data/train_images_patches_768_overlap/10044_00013.png'

# %%
train_df_768.iloc[0]['mask']
# Out:
# './../data/train_masks_patches_768_overlap/10044_00013.png'

# %%
train_df_768.iloc[0]['id']
# Out:
# 10044

# %%
# ---------------------------------------------------------------
# WARNING! THIS RESCALE IS INJECTED IN SWIN TRANSFORMER ALREADY!
#   RGB LAYER
# IT'S INPUTS HAVE TO BE IMAGE IN 0..1!
# ---------------------------------------------------------------

# %%
# mean = np.array([0.7720342, 0.74582646, 0.76392896])
# std = np.array([0.24745085, 0.26182273, 0.25782376])

# %%
train_transform= A.Compose([
#     A.Resize(512, 512, interpolation=cv.INTER_LINEAR),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.HueSaturationValue(p=0.25),
    A.ShiftScaleRotate(shift_limit=0.02, scale_limit=(-0.1, 0.5),rotate_limit=90, p=0.5),
    A.ElasticTransform(p=0.1, alpha=90, sigma=120 * 0.05, alpha_affine=120 * 0.03),
    A.GridDistortion(p=0.25),
    A.Blur(blur_limit=5, p=0.1),
    A.GaussNoise(var_limit=(20, 100), p=0.2),
    A.ChannelDropout(p=0.05),
    A.RandomGamma(p=0.1),
    A.RandomBrightnessContrast(p=0.2),
    A.Normalize(mean=[0, 0, 0], std=[1, 1, 1], 
                max_pixel_value=255, always_apply=True),
    albumentations.pytorch.ToTensorV2()
], p=1)

# %%
val_transform = A.Compose([
#     A.Resize(512, 512, interpolation = cv.INTER_LINEAR),
    A.Normalize(mean=[0, 0, 0], std=[1, 1, 1],
                 max_pixel_value=255, always_apply=True),
    albumentations.pytorch.ToTensorV2()
], p=1)

# %%
class HubmapDataset768(Dataset):
    def __init__(self, df, transform=None):

        self.df = df
        self.transform = transform
        self.length = len(self.df)

    def __str__(self):
        string = ''
        string += '\tlen = %d\n' % len(self)

        d = self.df.organ.value_counts().to_dict()
        for k in ['kidney', 'prostate', 'largeintestine', 'spleen', 'lung']:
            string +=  '%24s %3d (%0.3f) \n'%(k,d.get(k,0),d.get(k,0)/len(self.df))
        return string

    def __len__(self):
        return self.length

    def __getitem__(self, index):
        d = self.df.iloc[index]
        organ = ORGAN2ID[d['organ']]

        image = cv.cvtColor(cv.imread(d['image']), cv.COLOR_BGR2RGB) # .astype(np.float32) / 255.0
        mask = cv.imread(d['mask'], cv.IMREAD_GRAYSCALE)

        mask = mask / max(1, mask.max())
        
        mask_multiclass = mask * (organ + 1)
        
        data = {
            'image': image,
            'mask': mask_multiclass,
            'organ': organ,
        }
        
        upd_data = self.transform(image=data['image'], mask=data['mask'])

        data.update(upd_data)
        return data

# %%
def worker_init_fn(worker_id):
    torch_seed = torch.initial_seed()
    random.seed(torch_seed + worker_id)
    if torch_seed >= 2**30:  # make sure torch_seed + workder_id < 2**32
        torch_seed = torch_seed % 2**30
    np.random.seed(torch_seed + worker_id)
    random.seed(torch_seed + worker_id + 77777)

# %%
train_dataset = HubmapDataset768(train_df_768[train_df_768['fold'] != CURRENT_FOLD], train_transform)
val_dataset = HubmapDataset768(train_df_768[train_df_768['fold'] == CURRENT_FOLD], val_transform)

# %%
sample = train_dataset[1]
print('IMAGE')
print(sample['image'].shape)
print('image values: ', float(sample['image'].min()), float(sample['image'].max()))
plt.imshow(sample['image'].permute((1, 2, 0)))
plt.show()

print('MASK')
print(sample['mask'].shape)
print('mask values: ', sample['mask'].min(), sample['mask'].max())
plt.imshow(sample['mask'])
plt.show()
# Out:
# IMAGE
# torch.Size([3, 768, 768])
# image values:  0.0 0.960784375667572
# MASK
# torch.Size([768, 768])
# mask values:  tensor(0., dtype=torch.float64) tensor(2., dtype=torch.float64)

# %%
BATCH_SIZE = 5

# %%
loader_params = {'shuffle': True,
                 'num_workers': 0,
                 'worker_init_fn': worker_init_fn}
loader_train = DataLoader(train_dataset, 
                          batch_size=BATCH_SIZE, 
                          shuffle=True,
                          worker_init_fn=worker_init_fn,
                          num_workers=12
                         )
loader_val = DataLoader(val_dataset, 
                        batch_size=1, 
                        shuffle=False,
                        worker_init_fn=worker_init_fn,
                        num_workers=0
                       )

# %%
sample = val_dataset[2]
print('IMAGE')
print(sample['image'].shape)
print('image values: ', float(sample['image'].min()), float(sample['image'].max()))
plt.imshow(sample['image'].permute((1, 2, 0)))
plt.show()

print('MASK')
print(sample['mask'].shape)
print('mask values: ', sample['mask'].min(), sample['mask'].max())
plt.imshow(sample['mask'])
plt.show()
# Out:
# IMAGE
# torch.Size([3, 768, 768])
# image values:  0.027450982481241226 1.0
# MASK
# torch.Size([768, 768])
# mask values:  tensor(0., dtype=torch.float64) tensor(1., dtype=torch.float64)

# %% [markdown]
# # model

# %%
# !nvidia-smi
# Out:
# Fri Sep  2 18:07:57 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.152.00   Driver Version: 418.152.00   CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-DGXS...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   50C    P0    56W / 300W |   3359MiB / 32478MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-DGXS...  On   | 00000000:08:00.0 Off |                    0 |
# | N/A   51C    P0    56W / 300W |   1905MiB / 32478MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-DGXS...  On   | 00000000:0E:00.0 Off |                    0 |
# | N/A   58C    P0   230W / 300W |  15899MiB / 32478MiB |     55%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-DGXS...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   55C    P0   199W / 300W |  26269MiB / 32478MiB |    100%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
device = 'cuda:1'
DEVICE = device

# %%
encoder = coat_parallel_small
decoder = daformer_conv3x3

model = Net(encoder=encoder, decoder=decoder, n_classes=6)

# %% [markdown]
# # setting up SWA process (due to shared weights)

# %%
swa_model = AveragedModel(model)

# %%
for el in ['./checkpoint_fold_3/coat-small_ep_030_dice_0.775207.pt',
           './checkpoint_fold_3/coat-small_ep_030_dice_0.775207.pt',
           './checkpoint_fold_3/coat-small_ep_030_dice_0.775207.pt']:
    model.load_state_dict(torch.load(el, map_location=device))
    swa_model.update_parameters(model, )

# %%
for key in model.state_dict().keys():
    print(key)
# Out:
# rgb.mean
# rgb.std
# encoder.cls_token1
# encoder.cls_token2
# encoder.cls_token3
# encoder.cls_token4
# encoder.patch_embed1.proj.weight
# encoder.patch_embed1.proj.bias
# encoder.patch_embed1.norm.weight
# encoder.patch_embed1.norm.bias
# encoder.patch_embed2.proj.weight
# encoder.patch_embed2.proj.bias
# encoder.patch_embed2.norm.weight
# encoder.patch_embed2.norm.bias
# encoder.patch_embed3.proj.weight
# encoder.patch_embed3.proj.bias
# encoder.patch_embed3.norm.weight
# encoder.patch_embed3.norm.bias
# encoder.patch_embed4.proj.weight
# encoder.patch_embed4.proj.bias
# encoder.patch_embed4.norm.weight
# encoder.patch_embed4.norm.bias
# encoder.cpe1.proj.weight
# encoder.cpe1.proj.bias
# encoder.cpe2.proj.weight
# encoder.cpe2.proj.bias
# encoder.cpe3.proj.weight
# encoder.cpe3.proj.bias
# encoder.cpe4.proj.weight
# encoder.cpe4.proj.bias
# encoder.crpe1.conv_list.0.weight
# encoder.crpe1.conv_list.0.bias
# encoder.crpe1.conv_list.1.weight
# encoder.crpe1.conv_list.1.bias
# encoder.crpe1.conv_list.2.weight
# encoder.crpe1.conv_list.2.bias
# encoder.crpe2.conv_list.0.weight
# encoder.crpe2.conv_list.0.bias
# encoder.crpe2.conv_list.1.weight
# encoder.crpe2.conv_list.1.bias
# encoder.crpe2.conv_list.2.weight
# encoder.crpe2.conv_list.2.bias
# encoder.crpe3.conv_list.0.weight
# encoder.crpe3.conv_list.0.bias
# encoder.crpe3.conv_list.1.weight
# encoder.crpe3.conv_list.1.bias
# encoder.crpe3.conv_list.2.weight
# encoder.crpe3.conv_list.2.bias
# encoder.crpe4.conv_list.0.weight
# encoder.crpe4.conv_list.0.bias
# encoder.crpe4.conv_list.1.weight
# encoder.crpe4.conv_list.1.bias
# encoder.crpe4.conv_list.2.weight
# encoder.crpe4.conv_list.2.bias
# encoder.serial_blocks1.0.cpe.proj.weight
# encoder.serial_blocks1.0.cpe.proj.bias
# encoder.serial_blocks1.0.norm1.weight
# encoder.serial_blocks1.0.norm1.bias
# encoder.serial_blocks1.0.factoratt_crpe.qkv.weight
# encoder.serial_blocks1.0.factoratt_crpe.qkv.bias
# encoder.serial_blocks1.0.factoratt_crpe.proj.weight
# encoder.serial_blocks1.0.factoratt_crpe.proj.bias
# encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks1.0.norm2.weight
# encoder.serial_blocks1.0.norm2.bias
# encoder.serial_blocks1.0.mlp.fc1.weight
# encoder.serial_blocks1.0.mlp.fc1.bias
# encoder.serial_blocks1.0.mlp.fc2.weight
# encoder.serial_blocks1.0.mlp.fc2.bias
# encoder.serial_blocks1.1.cpe.proj.weight
# encoder.serial_blocks1.1.cpe.proj.bias
# encoder.serial_blocks1.1.norm1.weight
# encoder.serial_blocks1.1.norm1.bias
# encoder.serial_blocks1.1.factoratt_crpe.qkv.weight
# encoder.serial_blocks1.1.factoratt_crpe.qkv.bias
# encoder.serial_blocks1.1.factoratt_crpe.proj.weight
# encoder.serial_blocks1.1.factoratt_crpe.proj.bias
# encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks1.1.norm2.weight
# encoder.serial_blocks1.1.norm2.bias
# encoder.serial_blocks1.1.mlp.fc1.weight
# encoder.serial_blocks1.1.mlp.fc1.bias
# encoder.serial_blocks1.1.mlp.fc2.weight
# encoder.serial_blocks1.1.mlp.fc2.bias
# encoder.serial_blocks2.0.cpe.proj.weight
# encoder.serial_blocks2.0.cpe.proj.bias
# encoder.serial_blocks2.0.norm1.weight
# encoder.serial_blocks2.0.norm1.bias
# encoder.serial_blocks2.0.factoratt_crpe.qkv.weight
# encoder.serial_blocks2.0.factoratt_crpe.qkv.bias
# encoder.serial_blocks2.0.factoratt_crpe.proj.weight
# encoder.serial_blocks2.0.factoratt_crpe.proj.bias
# encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks2.0.norm2.weight
# encoder.serial_blocks2.0.norm2.bias
# encoder.serial_blocks2.0.mlp.fc1.weight
# encoder.serial_blocks2.0.mlp.fc1.bias
# encoder.serial_blocks2.0.mlp.fc2.weight
# encoder.serial_blocks2.0.mlp.fc2.bias
# encoder.serial_blocks2.1.cpe.proj.weight
# encoder.serial_blocks2.1.cpe.proj.bias
# encoder.serial_blocks2.1.norm1.weight
# encoder.serial_blocks2.1.norm1.bias
# encoder.serial_blocks2.1.factoratt_crpe.qkv.weight
# encoder.serial_blocks2.1.factoratt_crpe.qkv.bias
# encoder.serial_blocks2.1.factoratt_crpe.proj.weight
# encoder.serial_blocks2.1.factoratt_crpe.proj.bias
# encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks2.1.norm2.weight
# encoder.serial_blocks2.1.norm2.bias
# encoder.serial_blocks2.1.mlp.fc1.weight
# encoder.serial_blocks2.1.mlp.fc1.bias
# encoder.serial_blocks2.1.mlp.fc2.weight
# encoder.serial_blocks2.1.mlp.fc2.bias
# encoder.serial_blocks3.0.cpe.proj.weight
# encoder.serial_blocks3.0.cpe.proj.bias
# encoder.serial_blocks3.0.norm1.weight
# encoder.serial_blocks3.0.norm1.bias
# encoder.serial_blocks3.0.factoratt_crpe.qkv.weight
# encoder.serial_blocks3.0.factoratt_crpe.qkv.bias
# encoder.serial_blocks3.0.factoratt_crpe.proj.weight
# encoder.serial_blocks3.0.factoratt_crpe.proj.bias
# encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks3.0.norm2.weight
# encoder.serial_blocks3.0.norm2.bias
# encoder.serial_blocks3.0.mlp.fc1.weight
# encoder.serial_blocks3.0.mlp.fc1.bias
# encoder.serial_blocks3.0.mlp.fc2.weight
# encoder.serial_blocks3.0.mlp.fc2.bias
# encoder.serial_blocks3.1.cpe.proj.weight
# encoder.serial_blocks3.1.cpe.proj.bias
# encoder.serial_blocks3.1.norm1.weight
# encoder.serial_blocks3.1.norm1.bias
# encoder.serial_blocks3.1.factoratt_crpe.qkv.weight
# encoder.serial_blocks3.1.factoratt_crpe.qkv.bias
# encoder.serial_blocks3.1.factoratt_crpe.proj.weight
# encoder.serial_blocks3.1.factoratt_crpe.proj.bias
# encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks3.1.norm2.weight
# encoder.serial_blocks3.1.norm2.bias
# encoder.serial_blocks3.1.mlp.fc1.weight
# encoder.serial_blocks3.1.mlp.fc1.bias
# encoder.serial_blocks3.1.mlp.fc2.weight
# encoder.serial_blocks3.1.mlp.fc2.bias
# encoder.serial_blocks4.0.cpe.proj.weight
# encoder.serial_blocks4.0.cpe.proj.bias
# encoder.serial_blocks4.0.norm1.weight
# encoder.serial_blocks4.0.norm1.bias
# encoder.serial_blocks4.0.factoratt_crpe.qkv.weight
# encoder.serial_blocks4.0.factoratt_crpe.qkv.bias
# encoder.serial_blocks4.0.factoratt_crpe.proj.weight
# encoder.serial_blocks4.0.factoratt_crpe.proj.bias
# encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks4.0.norm2.weight
# encoder.serial_blocks4.0.norm2.bias
# encoder.serial_blocks4.0.mlp.fc1.weight
# encoder.serial_blocks4.0.mlp.fc1.bias
# encoder.serial_blocks4.0.mlp.fc2.weight
# encoder.serial_blocks4.0.mlp.fc2.bias
# encoder.serial_blocks4.1.cpe.proj.weight
# encoder.serial_blocks4.1.cpe.proj.bias
# encoder.serial_blocks4.1.norm1.weight
# encoder.serial_blocks4.1.norm1.bias
# encoder.serial_blocks4.1.factoratt_crpe.qkv.weight
# encoder.serial_blocks4.1.factoratt_crpe.qkv.bias
# encoder.serial_blocks4.1.factoratt_crpe.proj.weight
# encoder.serial_blocks4.1.factoratt_crpe.proj.bias
# encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.0.weight
# encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.0.bias
# encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.1.weight
# encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.1.bias
# encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.2.weight
# encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.2.bias
# encoder.serial_blocks4.1.norm2.weight
# encoder.serial_blocks4.1.norm2.bias
# encoder.serial_blocks4.1.mlp.fc1.weight
# encoder.serial_blocks4.1.mlp.fc1.bias
# encoder.serial_blocks4.1.mlp.fc2.weight
# encoder.serial_blocks4.1.mlp.fc2.bias
# encoder.parallel_blocks.0.norm12.weight
# encoder.parallel_blocks.0.norm12.bias
# encoder.parallel_blocks.0.norm13.weight
# encoder.parallel_blocks.0.norm13.bias
# encoder.parallel_blocks.0.norm14.weight
# encoder.parallel_blocks.0.norm14.bias
# encoder.parallel_blocks.0.factoratt_crpe2.qkv.weight
# encoder.parallel_blocks.0.factoratt_crpe2.qkv.bias
# encoder.parallel_blocks.0.factoratt_crpe2.proj.weight
# encoder.parallel_blocks.0.factoratt_crpe2.proj.bias
# encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.0.weight
# encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.0.bias
# encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.1.weight
# encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.1.bias
# encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.2.weight
# encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.2.bias
# encoder.parallel_blocks.0.factoratt_crpe3.qkv.weight
# encoder.parallel_blocks.0.factoratt_crpe3.qkv.bias
# encoder.parallel_blocks.0.factoratt_crpe3.proj.weight
# encoder.parallel_blocks.0.factoratt_crpe3.proj.bias
# encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.0.weight
# encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.0.bias
# encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.1.weight
# encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.1.bias
# encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.2.weight
# encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.2.bias
# encoder.parallel_blocks.0.factoratt_crpe4.qkv.weight
# encoder.parallel_blocks.0.factoratt_crpe4.qkv.bias
# encoder.parallel_blocks.0.factoratt_crpe4.proj.weight
# encoder.parallel_blocks.0.factoratt_crpe4.proj.bias
# encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.0.weight
# encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.0.bias
# encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.1.weight
# encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.1.bias
# encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.2.weight
# encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.2.bias
# encoder.parallel_blocks.0.norm22.weight
# encoder.parallel_blocks.0.norm22.bias
# encoder.parallel_blocks.0.norm23.weight
# encoder.parallel_blocks.0.norm23.bias
# encoder.parallel_blocks.0.norm24.weight
# encoder.parallel_blocks.0.norm24.bias
# encoder.parallel_blocks.0.mlp2.fc1.weight
# encoder.parallel_blocks.0.mlp2.fc1.bias
# encoder.parallel_blocks.0.mlp2.fc2.weight
# encoder.parallel_blocks.0.mlp2.fc2.bias
# encoder.parallel_blocks.0.mlp3.fc1.weight
# encoder.parallel_blocks.0.mlp3.fc1.bias
# encoder.parallel_blocks.0.mlp3.fc2.weight
# encoder.parallel_blocks.0.mlp3.fc2.bias
# encoder.parallel_blocks.0.mlp4.fc1.weight
# encoder.parallel_blocks.0.mlp4.fc1.bias
# encoder.parallel_blocks.0.mlp4.fc2.weight
# encoder.parallel_blocks.0.mlp4.fc2.bias
# encoder.parallel_blocks.1.norm12.weight
# encoder.parallel_blocks.1.norm12.bias
# encoder.parallel_blocks.1.norm13.weight
# encoder.parallel_blocks.1.norm13.bias
# encoder.parallel_blocks.1.norm14.weight
# encoder.parallel_blocks.1.norm14.bias
# encoder.parallel_blocks.1.factoratt_crpe2.qkv.weight
# encoder.parallel_blocks.1.factoratt_crpe2.qkv.bias
# encoder.parallel_blocks.1.factoratt_crpe2.proj.weight
# encoder.parallel_blocks.1.factoratt_crpe2.proj.bias
# encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.0.weight
# encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.0.bias
# encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.1.weight
# encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.1.bias
# encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.2.weight
# encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.2.bias
# encoder.parallel_blocks.1.factoratt_crpe3.qkv.weight
# encoder.parallel_blocks.1.factoratt_crpe3.qkv.bias
# encoder.parallel_blocks.1.factoratt_crpe3.proj.weight
# encoder.parallel_blocks.1.factoratt_crpe3.proj.bias
# encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.0.weight
# encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.0.bias
# encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.1.weight
# encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.1.bias
# encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.2.weight
# encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.2.bias
# encoder.parallel_blocks.1.factoratt_crpe4.qkv.weight
# encoder.parallel_blocks.1.factoratt_crpe4.qkv.bias
# encoder.parallel_blocks.1.factoratt_crpe4.proj.weight
# encoder.parallel_blocks.1.factoratt_crpe4.proj.bias
# encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.0.weight
# encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.0.bias
# encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.1.weight
# encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.1.bias
# encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.2.weight
# encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.2.bias
# encoder.parallel_blocks.1.norm22.weight
# encoder.parallel_blocks.1.norm22.bias
# encoder.parallel_blocks.1.norm23.weight
# encoder.parallel_blocks.1.norm23.bias
# encoder.parallel_blocks.1.norm24.weight
# encoder.parallel_blocks.1.norm24.bias
# encoder.parallel_blocks.1.mlp2.fc1.weight
# encoder.parallel_blocks.1.mlp2.fc1.bias
# encoder.parallel_blocks.1.mlp2.fc2.weight
# encoder.parallel_blocks.1.mlp2.fc2.bias
# encoder.parallel_blocks.1.mlp3.fc1.weight
# encoder.parallel_blocks.1.mlp3.fc1.bias
# encoder.parallel_blocks.1.mlp3.fc2.weight
# encoder.parallel_blocks.1.mlp3.fc2.bias
# encoder.parallel_blocks.1.mlp4.fc1.weight
# encoder.parallel_blocks.1.mlp4.fc1.bias
# encoder.parallel_blocks.1.mlp4.fc2.weight
# encoder.parallel_blocks.1.mlp4.fc2.bias
# encoder.parallel_blocks.2.norm12.weight
# encoder.parallel_blocks.2.norm12.bias
# encoder.parallel_blocks.2.norm13.weight
# encoder.parallel_blocks.2.norm13.bias
# encoder.parallel_blocks.2.norm14.weight
# encoder.parallel_blocks.2.norm14.bias
# encoder.parallel_blocks.2.factoratt_crpe2.qkv.weight
# encoder.parallel_blocks.2.factoratt_crpe2.qkv.bias
# encoder.parallel_blocks.2.factoratt_crpe2.proj.weight
# encoder.parallel_blocks.2.factoratt_crpe2.proj.bias
# encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.0.weight
# encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.0.bias
# encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.1.weight
# encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.1.bias
# encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.2.weight
# encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.2.bias
# encoder.parallel_blocks.2.factoratt_crpe3.qkv.weight
# encoder.parallel_blocks.2.factoratt_crpe3.qkv.bias
# encoder.parallel_blocks.2.factoratt_crpe3.proj.weight
# encoder.parallel_blocks.2.factoratt_crpe3.proj.bias
# encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.0.weight
# encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.0.bias
# encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.1.weight
# encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.1.bias
# encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.2.weight
# encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.2.bias
# encoder.parallel_blocks.2.factoratt_crpe4.qkv.weight
# encoder.parallel_blocks.2.factoratt_crpe4.qkv.bias
# encoder.parallel_blocks.2.factoratt_crpe4.proj.weight
# encoder.parallel_blocks.2.factoratt_crpe4.proj.bias
# encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.0.weight
# encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.0.bias
# encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.1.weight
# encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.1.bias
# encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.2.weight
# encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.2.bias
# encoder.parallel_blocks.2.norm22.weight
# encoder.parallel_blocks.2.norm22.bias
# encoder.parallel_blocks.2.norm23.weight
# encoder.parallel_blocks.2.norm23.bias
# encoder.parallel_blocks.2.norm24.weight
# encoder.parallel_blocks.2.norm24.bias
# encoder.parallel_blocks.2.mlp2.fc1.weight
# encoder.parallel_blocks.2.mlp2.fc1.bias
# encoder.parallel_blocks.2.mlp2.fc2.weight
# encoder.parallel_blocks.2.mlp2.fc2.bias
# encoder.parallel_blocks.2.mlp3.fc1.weight
# encoder.parallel_blocks.2.mlp3.fc1.bias
# encoder.parallel_blocks.2.mlp3.fc2.weight
# encoder.parallel_blocks.2.mlp3.fc2.bias
# encoder.parallel_blocks.2.mlp4.fc1.weight
# encoder.parallel_blocks.2.mlp4.fc1.bias
# encoder.parallel_blocks.2.mlp4.fc2.weight
# encoder.parallel_blocks.2.mlp4.fc2.bias
# encoder.parallel_blocks.3.norm12.weight
# encoder.parallel_blocks.3.norm12.bias
# encoder.parallel_blocks.3.norm13.weight
# encoder.parallel_blocks.3.norm13.bias
# encoder.parallel_blocks.3.norm14.weight
# encoder.parallel_blocks.3.norm14.bias
# encoder.parallel_blocks.3.factoratt_crpe2.qkv.weight
# encoder.parallel_blocks.3.factoratt_crpe2.qkv.bias
# encoder.parallel_blocks.3.factoratt_crpe2.proj.weight
# encoder.parallel_blocks.3.factoratt_crpe2.proj.bias
# encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.0.weight
# encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.0.bias
# encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.1.weight
# encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.1.bias
# encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.2.weight
# encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.2.bias
# encoder.parallel_blocks.3.factoratt_crpe3.qkv.weight
# encoder.parallel_blocks.3.factoratt_crpe3.qkv.bias
# encoder.parallel_blocks.3.factoratt_crpe3.proj.weight
# encoder.parallel_blocks.3.factoratt_crpe3.proj.bias
# encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.0.weight
# encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.0.bias
# encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.1.weight
# encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.1.bias
# encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.2.weight
# encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.2.bias
# encoder.parallel_blocks.3.factoratt_crpe4.qkv.weight
# encoder.parallel_blocks.3.factoratt_crpe4.qkv.bias
# encoder.parallel_blocks.3.factoratt_crpe4.proj.weight
# encoder.parallel_blocks.3.factoratt_crpe4.proj.bias
# encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.0.weight
# encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.0.bias
# encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.1.weight
# encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.1.bias
# encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.2.weight
# encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.2.bias
# encoder.parallel_blocks.3.norm22.weight
# encoder.parallel_blocks.3.norm22.bias
# encoder.parallel_blocks.3.norm23.weight
# encoder.parallel_blocks.3.norm23.bias
# encoder.parallel_blocks.3.norm24.weight
# encoder.parallel_blocks.3.norm24.bias
# encoder.parallel_blocks.3.mlp2.fc1.weight
# encoder.parallel_blocks.3.mlp2.fc1.bias
# encoder.parallel_blocks.3.mlp2.fc2.weight
# encoder.parallel_blocks.3.mlp2.fc2.bias
# encoder.parallel_blocks.3.mlp3.fc1.weight
# encoder.parallel_blocks.3.mlp3.fc1.bias
# encoder.parallel_blocks.3.mlp3.fc2.weight
# encoder.parallel_blocks.3.mlp3.fc2.bias
# encoder.parallel_blocks.3.mlp4.fc1.weight
# encoder.parallel_blocks.3.mlp4.fc1.bias
# encoder.parallel_blocks.3.mlp4.fc2.weight
# encoder.parallel_blocks.3.mlp4.fc2.bias
# encoder.parallel_blocks.4.norm12.weight
# encoder.parallel_blocks.4.norm12.bias
# encoder.parallel_blocks.4.norm13.weight
# encoder.parallel_blocks.4.norm13.bias
# encoder.parallel_blocks.4.norm14.weight
# encoder.parallel_blocks.4.norm14.bias
# encoder.parallel_blocks.4.factoratt_crpe2.qkv.weight
# encoder.parallel_blocks.4.factoratt_crpe2.qkv.bias
# encoder.parallel_blocks.4.factoratt_crpe2.proj.weight
# encoder.parallel_blocks.4.factoratt_crpe2.proj.bias
# encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.0.weight
# encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.0.bias
# encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.1.weight
# encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.1.bias
# encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.2.weight
# encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.2.bias
# encoder.parallel_blocks.4.factoratt_crpe3.qkv.weight
# encoder.parallel_blocks.4.factoratt_crpe3.qkv.bias
# encoder.parallel_blocks.4.factoratt_crpe3.proj.weight
# encoder.parallel_blocks.4.factoratt_crpe3.proj.bias
# encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.0.weight
# encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.0.bias
# encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.1.weight
# encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.1.bias
# encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.2.weight
# encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.2.bias
# encoder.parallel_blocks.4.factoratt_crpe4.qkv.weight
# encoder.parallel_blocks.4.factoratt_crpe4.qkv.bias
# encoder.parallel_blocks.4.factoratt_crpe4.proj.weight
# encoder.parallel_blocks.4.factoratt_crpe4.proj.bias
# encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.0.weight
# encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.0.bias
# encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.1.weight
# encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.1.bias
# encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.2.weight
# encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.2.bias
# encoder.parallel_blocks.4.norm22.weight
# encoder.parallel_blocks.4.norm22.bias
# encoder.parallel_blocks.4.norm23.weight
# encoder.parallel_blocks.4.norm23.bias
# encoder.parallel_blocks.4.norm24.weight
# encoder.parallel_blocks.4.norm24.bias
# encoder.parallel_blocks.4.mlp2.fc1.weight
# encoder.parallel_blocks.4.mlp2.fc1.bias
# encoder.parallel_blocks.4.mlp2.fc2.weight
# encoder.parallel_blocks.4.mlp2.fc2.bias
# encoder.parallel_blocks.4.mlp3.fc1.weight
# encoder.parallel_blocks.4.mlp3.fc1.bias
# encoder.parallel_blocks.4.mlp3.fc2.weight
# encoder.parallel_blocks.4.mlp3.fc2.bias
# encoder.parallel_blocks.4.mlp4.fc1.weight
# encoder.parallel_blocks.4.mlp4.fc1.bias
# encoder.parallel_blocks.4.mlp4.fc2.weight
# encoder.parallel_blocks.4.mlp4.fc2.bias
# encoder.parallel_blocks.5.norm12.weight
# encoder.parallel_blocks.5.norm12.bias
# encoder.parallel_blocks.5.norm13.weight
# encoder.parallel_blocks.5.norm13.bias
# encoder.parallel_blocks.5.norm14.weight
# encoder.parallel_blocks.5.norm14.bias
# encoder.parallel_blocks.5.factoratt_crpe2.qkv.weight
# encoder.parallel_blocks.5.factoratt_crpe2.qkv.bias
# encoder.parallel_blocks.5.factoratt_crpe2.proj.weight
# encoder.parallel_blocks.5.factoratt_crpe2.proj.bias
# encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.0.weight
# encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.0.bias
# encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.1.weight
# encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.1.bias
# encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.2.weight
# encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.2.bias
# encoder.parallel_blocks.5.factoratt_crpe3.qkv.weight
# encoder.parallel_blocks.5.factoratt_crpe3.qkv.bias
# encoder.parallel_blocks.5.factoratt_crpe3.proj.weight
# encoder.parallel_blocks.5.factoratt_crpe3.proj.bias
# encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.0.weight
# encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.0.bias
# encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.1.weight
# encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.1.bias
# encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.2.weight
# encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.2.bias
# encoder.parallel_blocks.5.factoratt_crpe4.qkv.weight
# encoder.parallel_blocks.5.factoratt_crpe4.qkv.bias
# encoder.parallel_blocks.5.factoratt_crpe4.proj.weight
# encoder.parallel_blocks.5.factoratt_crpe4.proj.bias
# encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.0.weight
# encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.0.bias
# encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.1.weight
# encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.1.bias
# encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.2.weight
# encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.2.bias
# encoder.parallel_blocks.5.norm22.weight
# encoder.parallel_blocks.5.norm22.bias
# encoder.parallel_blocks.5.norm23.weight
# encoder.parallel_blocks.5.norm23.bias
# encoder.parallel_blocks.5.norm24.weight
# encoder.parallel_blocks.5.norm24.bias
# encoder.parallel_blocks.5.mlp2.fc1.weight
# encoder.parallel_blocks.5.mlp2.fc1.bias
# encoder.parallel_blocks.5.mlp2.fc2.weight
# encoder.parallel_blocks.5.mlp2.fc2.bias
# encoder.parallel_blocks.5.mlp3.fc1.weight
# encoder.parallel_blocks.5.mlp3.fc1.bias
# encoder.parallel_blocks.5.mlp3.fc2.weight
# encoder.parallel_blocks.5.mlp3.fc2.bias
# encoder.parallel_blocks.5.mlp4.fc1.weight
# encoder.parallel_blocks.5.mlp4.fc1.bias
# encoder.parallel_blocks.5.mlp4.fc2.weight
# encoder.parallel_blocks.5.mlp4.fc2.bias
# decoder.mlp.0.0.weight
# decoder.mlp.0.1.weight
# decoder.mlp.0.1.bias
# decoder.mlp.0.1.running_mean
# decoder.mlp.0.1.running_var
# decoder.mlp.0.1.num_batches_tracked
# decoder.mlp.1.0.weight
# decoder.mlp.1.1.weight
# decoder.mlp.1.1.bias
# decoder.mlp.1.1.running_mean
# decoder.mlp.1.1.running_var
# decoder.mlp.1.1.num_batches_tracked
# decoder.mlp.1.3.mixing
# decoder.mlp.2.0.weight
# decoder.mlp.2.1.weight
# decoder.mlp.2.1.bias
# decoder.mlp.2.1.running_mean
# decoder.mlp.2.1.running_var
# decoder.mlp.2.1.num_batches_tracked
# decoder.mlp.2.3.mixing
# decoder.mlp.3.0.weight
# decoder.mlp.3.1.weight
# decoder.mlp.3.1.bias
# decoder.mlp.3.1.running_mean
# decoder.mlp.3.1.running_var
# decoder.mlp.3.1.num_batches_tracked
# decoder.mlp.3.3.mixing
# decoder.fuse.0.weight
# decoder.fuse.1.weight
# decoder.fuse.1.bias
# decoder.fuse.1.running_mean
# decoder.fuse.1.running_var
# decoder.fuse.1.num_batches_tracked
# logit.0.weight
# logit.0.bias
# logit.4.mixing
# logit.5.weight
# logit.5.bias
# aux_heads_serial.0.0.weight
# aux_heads_serial.0.0.bias
# aux_heads_serial.0.1.weight
# aux_heads_serial.0.1.bias
# aux_heads_serial.0.1.running_mean
# aux_heads_serial.0.1.running_var
# aux_heads_serial.0.1.num_batches_tracked
# aux_heads_serial.0.3.weight
# aux_heads_serial.0.3.bias
# aux_heads_serial.0.4.mixing
# aux_heads_serial.1.0.weight
# aux_heads_serial.1.0.bias
# aux_heads_serial.1.1.weight
# aux_heads_serial.1.1.bias
# aux_heads_serial.1.1.running_mean
# aux_heads_serial.1.1.running_var
# aux_heads_serial.1.1.num_batches_tracked
# aux_heads_serial.1.3.weight
# aux_heads_serial.1.3.bias
# aux_heads_serial.1.4.mixing
# aux_heads_serial.2.0.weight
# aux_heads_serial.2.0.bias
# aux_heads_serial.2.1.weight
# aux_heads_serial.2.1.bias
# aux_heads_serial.2.1.running_mean
# aux_heads_serial.2.1.running_var
# aux_heads_serial.2.1.num_batches_tracked
# aux_heads_serial.2.3.weight
# aux_heads_serial.2.3.bias
# aux_heads_serial.2.6.weight
# aux_heads_serial.2.6.bias
# aux_heads_serial.2.7.mixing
# aux_heads_serial.3.0.weight
# aux_heads_serial.3.0.bias
# aux_heads_serial.3.1.weight
# aux_heads_serial.3.1.bias
# aux_heads_serial.3.1.running_mean
# aux_heads_serial.3.1.running_var
# aux_heads_serial.3.1.num_batches_tracked
# aux_heads_serial.3.3.weight
# aux_heads_serial.3.3.bias
# aux_heads_serial.3.6.weight
# aux_heads_serial.3.6.bias
# aux_heads_serial.3.7.mixing
# aux_heads_parallel.0.0.weight
# aux_heads_parallel.0.0.bias
# aux_heads_parallel.0.1.weight
# aux_heads_parallel.0.1.bias
# aux_heads_parallel.0.1.running_mean
# aux_heads_parallel.0.1.running_var
# aux_heads_parallel.0.1.num_batches_tracked
# aux_heads_parallel.0.3.weight
# aux_heads_parallel.0.3.bias
# aux_heads_parallel.0.4.mixing
# aux_heads_parallel.1.0.weight
# aux_heads_parallel.1.0.bias
# aux_heads_parallel.1.1.weight
# aux_heads_parallel.1.1.bias
# aux_heads_parallel.1.1.running_mean
# aux_heads_parallel.1.1.running_var
# aux_heads_parallel.1.1.num_batches_tracked
# aux_heads_parallel.1.3.weight
# aux_heads_parallel.1.3.bias
# aux_heads_parallel.1.4.mixing
# aux_heads_parallel.2.0.weight
# aux_heads_parallel.2.0.bias
# aux_heads_parallel.2.1.weight
# aux_heads_parallel.2.1.bias
# aux_heads_parallel.2.1.running_mean
# aux_heads_parallel.2.1.running_var
# aux_heads_parallel.2.1.num_batches_tracked
# aux_heads_parallel.2.3.weight
# aux_heads_parallel.2.3.bias
# aux_heads_parallel.2.6.weight
# aux_heads_parallel.2.6.bias
# aux_heads_parallel.2.7.mixing
# aux_heads_parallel.3.0.weight
# aux_heads_parallel.3.0.bias
# aux_heads_parallel.3.1.weight
# aux_heads_parallel.3.1.bias
# aux_heads_parallel.3.1.running_mean
# aux_heads_parallel.3.1.running_var
# aux_heads_parallel.3.1.num_batches_tracked
# aux_heads_parallel.3.3.weight
# aux_heads_parallel.3.3.bias
# aux_heads_parallel.3.6.weight
# aux_heads_parallel.3.6.bias
# aux_heads_parallel.3.7.mixing

# %%
for key in model.state_dict().keys():
    W1 = model.state_dict()[key]
    W2 = swa_model.module.state_dict()[key]
    if not (torch.isclose(W1, W2).all().item()):
        print(key)
#     break
# Out:
# decoder.mlp.0.1.running_mean
# decoder.mlp.0.1.running_var
# decoder.mlp.0.1.num_batches_tracked
# decoder.mlp.1.1.running_mean
# decoder.mlp.1.1.running_var
# decoder.mlp.1.1.num_batches_tracked
# decoder.mlp.2.1.running_mean
# decoder.mlp.2.1.running_var
# decoder.mlp.2.1.num_batches_tracked
# decoder.mlp.3.1.running_mean
# decoder.mlp.3.1.running_var
# decoder.mlp.3.1.num_batches_tracked
# decoder.fuse.1.running_mean
# decoder.fuse.1.running_var
# decoder.fuse.1.num_batches_tracked
# aux_heads_serial.0.1.running_mean
# aux_heads_serial.0.1.running_var
# aux_heads_serial.0.1.num_batches_tracked
# aux_heads_serial.1.1.running_mean
# aux_heads_serial.1.1.running_var
# aux_heads_serial.1.1.num_batches_tracked
# aux_heads_serial.2.1.running_mean
# aux_heads_serial.2.1.running_var
# aux_heads_serial.2.1.num_batches_tracked
# aux_heads_serial.3.1.running_mean
# aux_heads_serial.3.1.running_var
# aux_heads_serial.3.1.num_batches_tracked

# %% [markdown]
# # calculating SWA try1

# %%
chkpts = []
for fname in sorted(glob('./checkpoint_fold_3/coat-small_ep_*_dice_*.pt')):
#     print(fname)
    bname = os.path.basename(fname)
    spt = bname.split('_')
    epoch = int(spt[2])
    dice = float(spt[4].rsplit('.', maxsplit=1)[0])
    print(epoch, dice)
    chkpts.append((fname, dice, epoch))
# Out:
# 0 0.721639
# 1 0.748904
# 2 0.772876
# 3 0.708495
# 4 0.769642
# 5 0.757454
# 6 0.762484
# 7 0.79247
# 8 0.777859
# 9 0.776535
# 10 0.77021
# 11 0.79063

# %%
chkpts = list(sorted(chkpts, key=lambda x: x[1]))

# %%
chkpts[-7:]
# Out:
# [('./checkpoint_fold_3/coat-small_ep_004_dice_0.769642.pt', 0.769642, 4),
#  ('./checkpoint_fold_3/coat-small_ep_010_dice_0.770210.pt', 0.77021, 10),
#  ('./checkpoint_fold_3/coat-small_ep_002_dice_0.772876.pt', 0.772876, 2),
#  ('./checkpoint_fold_3/coat-small_ep_009_dice_0.776535.pt', 0.776535, 9),
#  ('./checkpoint_fold_3/coat-small_ep_008_dice_0.777859.pt', 0.777859, 8),
#  ('./checkpoint_fold_3/coat-small_ep_011_dice_0.790630.pt', 0.79063, 11),
#  ('./checkpoint_fold_3/coat-small_ep_007_dice_0.792470.pt', 0.79247, 7)]

# %%
model.load_state_dict(torch.load(chkpts[-1][0], map_location=device))
# Out:
# <All keys matched successfully>

# %%
swa_model = AveragedModel(model)

# %%
for el in chkpts[-3:]:
    model.load_state_dict(torch.load(el[0], map_location=device))
    swa_model.update_parameters(model)

# %%
model.load_state_dict(torch.load(chkpts[-1][0], map_location=device))
# Out:
# <All keys matched successfully>

# %%
swa_state_dict = swa_model.state_dict()

# %%
for key in model.state_dict().keys():
    if 'num_batches_tracked' in key or \
        '.cpe.' in key or \
        '.crpe.' in key:
        print('replaced:', key)
        swa_state_dict['module.' + key] = model.state_dict()[key]
# Out:
# replaced: encoder.serial_blocks1.0.cpe.proj.weight
# replaced: encoder.serial_blocks1.0.cpe.proj.bias
# replaced: encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks1.0.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks1.1.cpe.proj.weight
# replaced: encoder.serial_blocks1.1.cpe.proj.bias
# replaced: encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks1.1.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks2.0.cpe.proj.weight
# replaced: encoder.serial_blocks2.0.cpe.proj.bias
# replaced: encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks2.0.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks2.1.cpe.proj.weight
# replaced: encoder.serial_blocks2.1.cpe.proj.bias
# replaced: encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks2.1.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks3.0.cpe.proj.weight
# replaced: encoder.serial_blocks3.0.cpe.proj.bias
# replaced: encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks3.0.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks3.1.cpe.proj.weight
# replaced: encoder.serial_blocks3.1.cpe.proj.bias
# replaced: encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks3.1.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks4.0.cpe.proj.weight
# replaced: encoder.serial_blocks4.0.cpe.proj.bias
# replaced: encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks4.0.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.serial_blocks4.1.cpe.proj.weight
# replaced: encoder.serial_blocks4.1.cpe.proj.bias
# replaced: encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.0.weight
# replaced: encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.0.bias
# replaced: encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.1.weight
# replaced: encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.1.bias
# replaced: encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.2.weight
# replaced: encoder.serial_blocks4.1.factoratt_crpe.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe2.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe3.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.0.factoratt_crpe4.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe2.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe3.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.1.factoratt_crpe4.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe2.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe3.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.2.factoratt_crpe4.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe2.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe3.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.3.factoratt_crpe4.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe2.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe3.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.4.factoratt_crpe4.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe2.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe3.crpe.conv_list.2.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.0.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.0.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.1.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.1.bias
# replaced: encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.2.weight
# replaced: encoder.parallel_blocks.5.factoratt_crpe4.crpe.conv_list.2.bias
# replaced: decoder.mlp.0.1.num_batches_tracked
# replaced: decoder.mlp.1.1.num_batches_tracked
# replaced: decoder.mlp.2.1.num_batches_tracked
# replaced: decoder.mlp.3.1.num_batches_tracked
# replaced: decoder.fuse.1.num_batches_tracked
# replaced: aux_heads_serial.0.1.num_batches_tracked
# replaced: aux_heads_serial.1.1.num_batches_tracked
# replaced: aux_heads_serial.2.1.num_batches_tracked
# replaced: aux_heads_serial.3.1.num_batches_tracked
# replaced: aux_heads_parallel.0.1.num_batches_tracked
# replaced: aux_heads_parallel.1.1.num_batches_tracked
# replaced: aux_heads_parallel.2.1.num_batches_tracked
# replaced: aux_heads_parallel.3.1.num_batches_tracked

# %%
swa_model.load_state_dict(swa_state_dict)
# Out:
# <All keys matched successfully>

# %%
# model.load_state_dict(torch.load('./checkpoint_fold_3_SAM/mit-b2_ep_501_dice_0.772775.pt', map_location=device))

# %% [markdown]
# # don't forget to call this after training

# %%
# swa_model.load_state_dict(torch.load('..'))

# %%
device
# Out:
# 'cuda:1'

# %%
swa_model = swa_model.to(device)

# %%
class HubmapDataset768(Dataset):
    def __init__(self, df, transform=None):

        self.df = df
        self.transform = transform
        self.length = len(self.df)

    def __str__(self):
        string = ''
        string += '\tlen = %d\n' % len(self)

        d = self.df.organ.value_counts().to_dict()
        for k in ['kidney', 'prostate', 'largeintestine', 'spleen', 'lung']:
            string +=  '%24s %3d (%0.3f) \n'%(k,d.get(k,0),d.get(k,0)/len(self.df))
        return string

    def __len__(self):
        return self.length

    def __getitem__(self, index):
        if index % 100 == 0:
            print(index)
        d = self.df.iloc[index]
        organ = ORGAN2ID[d['organ']]

        image = cv.cvtColor(cv.imread(d['image']), cv.COLOR_BGR2RGB) # .astype(np.float32) / 255.0
        
        image = self.transform(image=image)['image'].to(device)

        return {'image': image, 'organ': organ}

# %%
val_transform = A.Compose([
#     A.Resize(512, 512, interpolation = cv.INTER_LINEAR),
    A.Normalize(mean=[0, 0, 0], std=[1, 1, 1],
                 max_pixel_value=255, always_apply=True),
    albumentations.pytorch.ToTensorV2()
], p=1)

# %%
train_dataset = HubmapDataset768(train_df_768[train_df_768['fold'] != CURRENT_FOLD], val_transform)
loader_params = {'shuffle': True,
                 'num_workers': 0,
                 'worker_init_fn': worker_init_fn}
loader_train = DataLoader(train_dataset, 
                          batch_size=BATCH_SIZE, 
                          shuffle=False,
                          worker_init_fn=worker_init_fn,
                          num_workers=0
                         )

# %%
torch.optim.swa_utils.update_bn(loader_train, swa_model)
# Out:
# 0
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900

# %%
torch.save(swa_model.state_dict(), os.path.join(
                    './checkpoint_fold_{}'.format(CURRENT_FOLD), 
                    'coat-small-organ-token-fold3_TOP_3_BEST.pt'
                ))

# %%
# no amp version

# %%
for epoch in range(0, N_EPOCHS):
    criterion_image, criterion_aux = criterion_schedule(epoch)
    
    model.train()
    
    batch_train_loss = []
    
    for iteration, batch in enumerate(loader_train):
        global_it += 1
        
        batch['image'] = batch['image'].to(device)
        batch['mask' ] = batch['mask' ].to(device, dtype=torch.long)
#         batch['organ'] = batch['organ'].cuda()
        
        unfreeze_running_stats(model)

        output = model(batch)
        loss0      = criterion_image(output['out_logits'],   batch['mask'])
        loss_aux1  = criterion_aux  (output['aux1_logits'],  batch['mask']).mean()
        loss_aux2  = criterion_aux  (output['aux2_logits'],  batch['mask']).mean()
        loss = loss0 + 0.05 * loss_aux1 + 0.2 * loss_aux2
        
        loss.backward()
        optimizer.first_step(zero_grad=True)
        
        freeze_running_stats(model)  # <- this is the important line

        output = model(batch)
        loss0      = criterion_image(output['out_logits'],   batch['mask'])
        loss_aux1  = criterion_aux  (output['aux1_logits'],  batch['mask']).mean()
        loss_aux2  = criterion_aux  (output['aux2_logits'],  batch['mask']).mean()
        loss_act = loss0 + 0.05 * loss_aux1 + 0.2 * loss_aux2
            
        loss_act.backward()
        
        optimizer.second_step(zero_grad=True)
                 
        batch_train_loss.append(loss_act.item())          
        
        if global_it % VIRTUAL_BATCH_SIZE == 0:
            train_loss.append(np.mean(batch_train_loss))
            batch_train_loss = []
            lr_hist.append(optimizer.param_groups[0]['lr'])
            scheduler_warmup.step()
                    
        if global_it % (VIRTUAL_BATCH_SIZE * 5) == 0:
            log('==> Epoch {} ({:03d}/{:03d}) | loss: {:.5f}'.format(epoch, iteration, len(loader_train), loss.item()))


        if iteration % (VIRTUAL_BATCH_SIZE * 40) == 0:
            clear_output()

            plt.figure(figsize=(10, 5))
            plt.yscale('log')
            plt.plot(train_loss)
            plt.grid()
            plt.show()
              
            plt.figure(figsize=(10, 4))
            plt.plot(lr_hist, color='red')
            plt.title('lr')
            plt.grid()
            plt.show()
        
    if epoch > SWA_START:
        swa_model.update_parameters(model)
        swa_scheduler.step()
        
    # val -------------------------------
    if epoch % 3 == 0:
        log('Eval')
        model.eval()

        with torch.no_grad():
            val_res = validate(val_df_id, model)
            val_dice = np.mean(val_res['dices'])
            log('DICE: {}'.format(val_dice))
            for key, value in val_res['by_organ'].items():
                log('{:20}: {:6.5f}'.format(key, np.mean(value)))

            torch.save(model.state_dict(), os.path.join(
                PTH_CKPT, 
                'mit-b2_ep_{:03d}_dice_{:08.6f}.pt'.format(epoch, val_dice)
            )) 
            if epoch > SWA_START:
                torch.save(swa_model.state_dict(), os.path.join(
                    PTH_CKPT, 
                    'mit-b2_swa_ep_{:03d}_dice_{:08.6f}.pt'.format(epoch, val_dice)
                )) 
            logfile.flush()
