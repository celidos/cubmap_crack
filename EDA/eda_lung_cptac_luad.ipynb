# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import tifffile
import matplotlib.pyplot as plt

# %%
FILENAME = './../other_data/lung_CPTAC_LUAD/C3L-00368-26.svs'

# %%
x = tifffile.imread(FILENAME, key=0)
plt.figure(figsize=(12, 12))
plt.imshow(x)

plt.show()
