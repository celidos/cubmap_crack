# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from glob import glob

# %%
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 36.4 MB/s eta 0:00:01
# ...

# %%
from pydicom import dcmread
from pydicom.data import get_testdata_file

# %%
def plot_dcm_file(fname):
    print(fname)
    ds = dcmread(fname)
    plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
    plt.show()

# %%
FNAME = './../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-02-1997-CT ABDOMEN PELVIS W CONT-75829/1.000000-Topogram  0.6  T20s-90782/1-1.dcm'

# %%
plot_dcm_file(FNAME)
# Out:
# ./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-02-1997-CT ABDOMEN PELVIS W CONT-75829/1.000000-Topogram  0.6  T20s-90782/1-1.dcm

# %%
files = glob('./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/*/*/*/*.dcm')

# %%
len(files)
# Out:
# 8387

# %%
for fname in list(files)[::100]:
    plot_dcm_file(fname)
# Out:
# ./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-G4-6310/09-18-2000-CT CHEST ABD PELVIS W CONTR-08849/1.000000-LOCALIZER-06018/1-1.dcm
# ./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-G4-6310/09-18-2000-CT CHEST ABD PELVIS W CONTR-08849/2.000000- NONE -69306/2-034.dcm
# ./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-23-1997-CT ABDOMEN PELVIS W CONT-54472/2.000000-AbdPelvis  5.0  B30f-72811/1-09.dcm
# ./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-02-1997-CT ABDOMEN PELVIS W CONT-75829/2.000000-AbdomenPelv  5.0  B30f-00432/1-62.dcm
# ./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-CK-5916/03-18-1995-ECT008IV   CT ABDOMEN W CO-59531/2.000000-AbdRoutine 5.0 B30f-95590/1-15.dcm
# ...

# %%
files = glob('./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/*/*/*/*')

# %%
for x in files:
    if not x.endswith('.dcm'):
        print(x)

# %%
files = glob('./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/*/*/*')

# %%
files
# Out:
# ['./../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-G4-6310/09-18-2000-CT CHEST ABD PELVIS W CONTR-08849/1.000000-LOCALIZER-06018',
#  './../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-G4-6310/09-18-2000-CT CHEST ABD PELVIS W CONTR-08849/2.000000- NONE -69306',
#  './../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-23-1997-CT ABDOMEN PELVIS W CONT-54472/1.000000-Topogram  0.6  T20s-64838',
#  './../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-23-1997-CT ABDOMEN PELVIS W CONT-54472/2.000000-AbdPelvis  5.0  B30f-72811',
#  './../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-02-1997-CT ABDOMEN PELVIS W CONT-75829/1.000000-Topogram  0.6  T20s-90782',
#  './../other_data/intestine_TCGA_COAD/TCIA_TCGA-COAD_09-16-2015/TCGA-COAD/TCGA-AY-4070A/12-02-1997-CT ABDOMEN PELVIS W CONT-75829/2.000000-AbdomenPelv  5.0  B30f-00432',
# ...
