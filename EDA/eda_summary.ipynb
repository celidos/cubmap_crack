# %% [markdown]
# # Таблица

# %% [markdown]
# ## post https://www.kaggle.com/competitions/hubmap-organ-segmentation/discussion/333886**HuBMAP
#
# **Hacking the Kidney**
#
# Kidney
#
# 31 GB
#
# Выгружен, 15 огромных фреймов ("стейков") c разметкой TFU, 5 фреймов без разметки
#
# ![kidney](images/kidney_kaggle.png)
#
# **HuBMAP**
#
# Kidney
#
# 70 GB
#
# 46 фреймов. Выгружен самописным лоадером. Разметка неизвестно, есть или нет. Неизвестно, пересекается с `Hacking the Kidney` или нет.
#
# ![kidney](images/kidney_hubmap.png)

# %% [markdown]
# --------------
#
# Kidney (почки)
#
# **1. (Hubmap): https://www.kaggle.com/competitions/hubmap-kidney-segmentation/data**
#
# Это и есть `Hacking the Kidney`
#
# **2. CPTAC-CCRCC: https://wiki.cancerimagingarchive.net/display/Public/CPTAC-CCRCC**
#
# $$TODO$$

# %% [markdown]
# ---------------
#
# Large intestine (кишечник)
#
#
# **1. TCGA COAD: https://wiki.cancerimagingarchive.net/display/Public/TCGA-COAD**
#
# Выкачан, есть только радиографические снимки, tissue нет, возможно не подходит
#
# ![index.png](images/index.png)
#
# **2. CPTAC-COAD: https://wiki.cancerimagingarchive.net/display/Public/CPTAC-COAD**
#
# Примерно 340 крупных снимков
#
# 66 GB
#
# ![heh](images/intestine.png)
#
# Это говнище качается через плагин Aspera через локалку (( потом надо будет залить на сервер (1-2 дня)

# %% [markdown]
# ---------------
#
# Lung (легкие)
#
# **1. TCGA LUAD: https://wiki.cancerimagingarchive.net/display/Public/TCGA-LUAD**
#
# Выгружен, только рентген, нет tissues
#
# ![heh](images/tcga_luad.png)
#
# **2. TCGA LUSC: https://wiki.cancerimagingarchive.net/display/Public/TCGA-LUSC**
#
# 14 GB
#
# Выгружен, только рентген, нет tissues
#
# ![lusc](images/tcga_lusc.png)
#
# **3. Lung-ACDC: https://acdc-lunghp.grand-challenge.org/Challenge/**
#
# $$TODO$$
#
# **4. CPTAC-LSCC: https://wiki.cancerimagingarchive.net/display/Public/CPTAC-LSCC**
#
# Состоит из двух частей: Images (DICOM) и Tissues (SVS)
#
# Images
#
# 28 GB
#
# выкачаны, только рентген, нет tissues:
#
# ![lung](images/lung_cptac_lscc.png)
#
# Tissues: ??
#
# 414 GB
#
# sample `C3L-00568-23.svs`
#
# ![image](images/lung_cptac_lscc_tissue.png)
#
# $$TODO$$
#
# `Aspera :(`
#
# **5. CPTAC-LUAD: https://wiki.cancerimagingarchive.net/display/Public/CPTAC-LUAD**
#
# Есть
#
# Images 28 GB
#
# $$TODO$$
#
# Tissues   425 GB  `Aspera :((`
#
# loading sample `C3L-00368-26.svs`
#
# ![image](images/lung_cptac_luad.png)
#
# $$TODO$$

# %% [markdown]
# ---------------
#
# Prostate
#
# **1. TCGA-PRAD: https://wiki.cancerimagingarchive.net/display/Public/TCGA-PRAD**
#
# $$TODO$$
#
# **2. PANDAs: https://www.kaggle.com/competitions/prostate-cancer-grade-assessment**
#
# _Не выкачан_
#
# ~10600 снимков TIFF по 20 мб каждый
#
# 411 GB
#
# Содержит рак
#
# ![image](images/prostate_panda.png)
#
# ![image](images/prostate_panda_2.png)
#
# ![image](images/gysto.jpg)
#
# Мб отправлять через Kaggle на станцию?
#
# **1. https://www.cancerimagingarchive.net/histopathology-imaging-on-tcia/**
#
# $$TODO$$
#
# **2. https://wiki.cancerimagingarchive.net/display/Public/PROSTATE-MRI**
#
# $$TODO$$
#
# ---------------
#
# Kidney + Large intestine + Lung + Spleen + Prostate:
#
# **(HPA) https://www.proteinatlas.org/about/download**
