# %%
from glob import glob
from matplotlib import pyplot as plt

# %%
from pydicom import dcmread
from pydicom.data import get_testdata_file

# %%
def plot_dcm_file(fname):
    print(fname)
    ds = dcmread(fname)
    plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
    plt.show()

# %%
FNAME = './../other_data/lung_TCGA_LUSC/doiJNLP-TCGA-LUSC-01-30-2017/TCGA-LUSC/TCGA-34-5239/04-15-1993-PTCTSKTHPET  CT TUMOR-92693/2.000000-LOW DOSE C- CHEST-99239/1-001.dcm'

# %%
plot_dcm_file(FNAME)
# Out:
# ./../other_data/lung_TCGA_LUSC/doiJNLP-TCGA-LUSC-01-30-2017/TCGA-LUSC/TCGA-34-5239/04-15-1993-PTCTSKTHPET  CT TUMOR-92693/2.000000-LOW DOSE C- CHEST-99239/1-001.dcm

# %%
len(glob('./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/*/*/*/*.dcm'))
# Out:
# 2665

# %%
for fname in list(glob('./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/*/*/*/*.dcm'))[::100]:
    plot_dcm_file(fname)
# Out:
# ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-38-6178/02-18-2002-Outside Read or Comparison BODY CT-06083/202.000000-Reformatted-22425/1-040.dcm
# ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-38-6178/02-18-2002-Outside Read or Comparison BODY CT-06083/202.000000-Reformatted-22425/1-138.dcm
# ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-50-6593/01-06-2000-CT THORAX  WITHOUT CON-73125/3.000000-Recon 2 HELICAL 5s-10784/1-101.dcm
# ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-50-8460/02-05-2003-CT BIOPSY LUNG OR MEDI-11757/3.000000-AXIAL MODE-63298/12-01.dcm
# ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-50-8460/01-16-2003-CT CHEST WITHOUT CONTR-00307/4.000000-Recon 3 CHEST-.8-76990/2-021.dcm
# ...

# %%
ds = dcmread(FNAME)

# %%
dir(ds)
# Out:
# ['AccessionNumber',
#  'AcquisitionDate',
#  'AcquisitionNumber',
#  'AcquisitionTime',
#  'AdditionalPatientHistory',
#  'BitsAllocated',
#  'BitsStored',
#  'BodyPartExamined',
#  'Columns',
#  'ContentDate',
#  'ContentTime',
#  'ContrastBolusAgent',
#  'ContrastBolusRoute',
#  'ConvolutionKernel',
#  'DataCollectionDiameter',
#  'DeidentificationMethod',
#  'DeidentificationMethodCodeSequence',
#  'DistanceSourceToDetector',
#  'DistanceSourceToPatient',
#  'Exposure',
#  'ExposureTime',
#  'FilterType',
#  'FocalSpots',
#  'FrameOfReferenceUID',
#  'GantryDetectorTilt',
#  'GeneratorPower',
#  'HighBit',
#  'ImageOrientationPatient',
#  'ImagePositionPatient',
#  'ImageType',
#  'InstanceCreationDate',
#  'InstanceCreationTime',
#  'InstanceNumber',
#  'KVP',
#  'LongitudinalTemporalInformationModified',
#  'Manufacturer',
#  'ManufacturerModelName',
#  'Modality',
#  'PatientAge',
#  'PatientBirthDate',
#  'PatientID',
#  'PatientIdentityRemoved',
#  'PatientName',
# ...

# %%
ds.ImageDimensions
# Out:
# 2

# %%
# !du -h ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/
# Out:
# 28M	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/06-27-1983-70350/2.000000-Chest Routine 1-87612
# 1.1M	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/06-27-1983-70350/1.000000-Topogram-76216
# 29M	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/06-27-1983-70350
# 520K	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/04-21-1983-82105/1.000000-Topogram-12765
# 524K	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/04-21-1983-82105
# 29M	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/

# %%
# !du -h ./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/06-27-1983-70350/2.000000-Chest\ Routine\ 1-87612
# Out:
# 28M	./../other_data/lung_TCGA_LUAD/doiJNLP-TCGA-LUAD-01-30-2017/TCGA-LUAD/TCGA-17-Z028/06-27-1983-70350/2.000000-Chest Routine 1-87612
