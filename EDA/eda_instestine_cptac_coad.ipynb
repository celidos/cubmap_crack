# %%
# !pip install openslide-python

# %%
# !apt update && apt install -y openslide-tools

# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH":/usr/lib/x86_64-linux-gnu:"

# %% [markdown]
# # tifffile

# %%
import tifffile
import matplotlib.pyplot as plt

# %%
FILENAME = './../other_data/instestine_CPTAC_COAD/01CO001-760f15d2-444c-4deb-b133-62f3ca.svs'

# %%
x = tifffile.imread(FILENAME, key=0)
plt.imshow(x)
plt.show()

# %%
x = tifffile.imread(FILENAME, key=1)
plt.imshow(x)
plt.show()

# %%
x = tifffile.imread(FILENAME, key=2)
plt.imshow(x)
plt.show()

# %%
x = tifffile.imread(FILENAME, key=3)
plt.imshow(x)
plt.show()

# %%
x = tifffile.imread(FILENAME, key=4)
plt.imshow(x)
plt.show()

# %%
x = tifffile.imread(FILENAME, key=5)
plt.imshow(x)
plt.show()

# %%
# x = tifffile.imread(FILENAME, key=6)
# plt.imshow(x)
# plt.show()

# %% [markdown]
# # 6th layer does not exist

# %% [markdown]
# Total files: 372

# %% [markdown]
# Total size: 66 GB

# %% [markdown]
# Качать - геморрой
