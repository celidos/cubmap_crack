# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import pandas as pd
from collections import Counter
from PIL import Image

# %% [markdown]
# # train

# %%
df = pd.read_csv('./../data/train.csv')

# %%
df.head()
# Out:
#       id     organ data_source  img_height  img_width  pixel_size  \
# 0  10044  prostate         HPA        3000       3000         0.4
# 1  10274  prostate         HPA        3000       3000         0.4
# 2  10392    spleen         HPA        3000       3000         0.4
# 3  10488      lung         HPA        3000       3000         0.4
# 4  10610    spleen         HPA        3000       3000         0.4
#
#    tissue_thickness                                                rle   age  \
# 0                 4  1459676 77 1462675 82 1465674 87 1468673 92 14...  37.0
# 1                 4  715707 2 718705 8 721703 11 724701 18 727692 3...  76.0
# 2                 4  1228631 20 1231629 24 1234624 40 1237623 47 12...  82.0
# 3                 4  3446519 15 3449517 17 3452514 20 3455510 24 34...  78.0
# 4                 4  478925 68 481909 87 484893 105 487863 154 4908...  21.0
#
#       sex
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4  Female

# %%
set(df['pixel_size'])
# Out:
# {0.4}

# %%
set(df['tissue_thickness'])
# Out:
# {4}

# %%
sizes = [list(df['img_width']), list(df['img_height'])]
sizes = list(zip(*sizes))

# %%
Counter(sizes)
# Out:
# Counter({(3000, 3000): 326,
#          (2867, 2867): 1,
#          (2654, 2654): 2,
#          (2727, 2727): 1,
#          (2680, 2680): 1,
#          (2539, 2539): 1,
#          (2631, 2631): 2,
#          (2790, 2790): 2,
#          (2942, 2942): 2,
#          (2308, 2308): 1,
#          (2764, 2764): 2,
#          (2783, 2783): 1,
#          (2869, 2869): 1,
#          (2760, 2760): 1,
#          (2630, 2630): 1,
#          (2511, 2511): 1,
#          (2416, 2416): 2,
#          (2593, 2593): 1,
#          (2675, 2675): 1,
#          (3070, 3070): 1})

# %% [markdown]
# # test

# %%
test_df = pd.read_csv('./../data/test.csv')

# %%
test_df.head()
# Out:
#       id   organ data_source  img_height  img_width  pixel_size  \
# 0  10078  spleen      Hubmap        2023       2023      0.4945
#
#    tissue_thickness
# 0                 4

# %% [markdown]
# # images

# %%
img = cv.imread('./../data/train_images/12483.tiff')

# %%
img.shape, img.dtype
# Out:
# ((3000, 3000, 3), dtype('uint8'))

# %%
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.show()

# %% [markdown]
# # RLE DECODE
