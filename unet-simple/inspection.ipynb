# %%
import pandas as pd

# %%
df = pd.read_csv('./logs/default/version_4/metrics.csv')

# %%
df
# Out:
#     train_loss  epoch  step  val_loss
# 0     0.820931      0     4       NaN
# 1     0.792189      0     9       NaN
# 2     0.776901      0    14       NaN
# 3          NaN      0    16  0.803634
# 4     0.807837      1    19       NaN
# 5     0.776548      1    24       NaN
# 6     0.798902      1    29       NaN
# 7          NaN      1    33  0.795124
# 8     0.793432      2    34       NaN
# 9     0.763764      2    39       NaN
# 10    0.689749      2    44       NaN
# 11    0.825346      2    49       NaN
# 12         NaN      2    50  0.787599
# 13    0.693095      3    54       NaN
# 14    0.751103      3    59       NaN
# 15    0.695880      3    64       NaN
# 16         NaN      3    67  0.784957
# 17    0.791777      4    69       NaN
# 18    0.767156      4    74       NaN
# 19    0.760050      4    79       NaN
# 20    0.756659      4    84       NaN
# 21         NaN      4    84  0.777543
# 22    0.852582      5    89       NaN
# 23    0.798669      5    94       NaN
# ...

# %%
# !tar -cvf checkpoint.tar ./logs/default/version_4
# Out:
# ./logs/default/version_4/
# ./logs/default/version_4/checkpoints/
# ./logs/default/version_4/checkpoints/epoch=9-step=169.ckpt
# ./logs/default/version_4/hparams.yaml
# ./logs/default/version_4/metrics.csv
