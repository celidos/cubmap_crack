# %%
# !python3 main_pretrain.py \
    --batch_size 32 \
    --accum_iter 2 \
    --epochs 2000 \
    --model simmim_pvt_small_256 \
    --input_size 256 \
    --token_size 16 \
    --mask_regular \
    --data_path ./../data_ready \
    --output_dir ./../output_dir \
    --log_dir ./../output_dir \
    --device cuda:3 \
    --seed 0\
    --load_from ./../checkpoint-99-model.pth
# Out:
# Not using distributed mode
# [14:44:49.523786] job dir: /workspace/nfs/cando/epockonechny/other/pockonechnyy/HUBMAP/cubmap_crack/ummae-pvt/UM-MAE-main
# [14:44:49.523864] Namespace(accum_iter=2,
# batch_size=32,
# bf16=False,
# blr=0.001,
# data_path='./../data_ready',
# device='cuda:3',
# dist_on_itp=False,
# dist_url='env://',
# distributed=False,
# epochs=2000,
# input_size=256,
# load_from='./../checkpoint-99-model.pth',
# local_rank=-1,
# log_dir='./../output_dir',
# lr=None,
# mask_ratio=0.75,
# mask_regular=True,
# min_lr=0.0,
# model='simmim_pvt_small_256',
# norm_pix_loss=False,
# num_workers=8,
# output_dir='./../output_dir',
# pin_mem=True,
# resume='',
# seed=0,
# start_epoch=0,
# token_size=16,
# vis_mask_ratio=0.0,
# warmup_epochs=40,
# weight_decay=0.05,
# world_size=1)
# ...

# %%
# !pip install timm==0.4.5
